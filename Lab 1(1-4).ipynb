# %% [markdown]
# ## Практическое задание №1

# %% [markdown]
# **Это жирный текст**, *а это курсивный*
#
# ## Нумерованный список:
#
# 1. Пункт 1
# 2. Пункт 2
# 3. Пункт 3
#
# ## Маркированный список:
#
# - Элемент 1
# - Элемент 2
# - Элемент 3
#
# ## Формула:
#
# $S = \frac{a}{1-r}$, $|r|<1$
#
# ## Изображение:
#
# ![photo_2025-04-16_08-44-19.jpg](attachment:bd52d32c-a253-44df-a929-22f55af59c66.jpg)

# %%
a = input()
print(f'Привет, {a}! Добро пожаловать в JupyterLab')
# Out:
#  Rei
# Привет, Rei! Добро пожаловать в JupyterLab

# %% [markdown]
# ## Практическое задание №2

# %%
import os
with open("example.txt", "w") as f:
    f.write("Первая строка\n")
    f.write("Вторая строка\n")
with open("example.txt", "r") as f:
    content = f.read()
    print("Содержимое файла:\n", content)
print("Файл существует:", os.path.exists("example.txt"))

os.remove("example.txt")
print("Файл удален")
# Out:
# Содержимое файла:
#  Первая строка
# Вторая строка
#
# Файл существует: True
# Файл удален

# %% [markdown]
# ## Практическое задание №3

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %time sum(range(1000000))
# Out:
# CPU times: total: 31.2 ms
# Wall time: 29.5 ms
# 499999500000

# %%
# %%timeit
total = 0
for i in range(1000000):
    total += i
# Out:
# 56.6 ms ± 729 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%writefile my_script.py
print("Hello, world!")
# Out:
# Writing my_script.py

# %%
# %run my_script.py
# Out:
# Hello, world!

# %% [markdown]
# ## Практическое задание №4

# %%
# %ls
# Out:
#  ’®¬ ў гбва®©бвўҐ D Ё¬ҐҐв ¬ҐвЄг S.Nartshaev
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : D216-E110
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ D:\Anal\Scripts\notebook
#
# 21.05.2025  08:43    <DIR>          .
# 21.05.2025  08:43    <DIR>          ..
# 16.04.2025  08:56    <DIR>          .ipynb_checkpoints
# 21.05.2025  08:42           330я032 Lab 1.ipynb
# 16.04.2025  09:25                24 my_script.py
# 09.04.2025  09:25           185я468 Otnoshenie_lyudey_k_Iskusstvennomu_intellektu (1).csv
# 21.05.2025  08:43    <DIR>          test1_folder
# 09.04.2025  09:30            63я855 ЏаЁ¬Ґал jupyter lab.ipynb
# 09.04.2025  09:04            49я054 ЏаЁ¬Ґал jupyter notebook.ipynb
#                5 д ©«®ў        628я433 Ў ©в
#                4 Ї Ї®Є  15я907я942я400 Ў ©в бў®Ў®¤­®

# %%
# %history
# Out:
# %run my_script.py
# # Практическое задание №2
# # Практическое задание №2
# # Практическое задание №2
# !dir
# !where python
# !dir
# !echo.> example.txt
# !move example.txt test_folder\
# !dir test_folder\
# !del test_folder\example.txt
# !dir test_folder\
# !dir
# !mkdir test1_folder
# !dir
# !echo.> example.txt
# !move example.txt test1_folder/
# !dir test1_folder
# !del test1_folder\example.txt
# !dir test1_folder
# %clear
# %ls
# %history

# %%
# !where python
# Out:
# C:\Users\stasz\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !mkdir new_folder
# !rmdir new_folder
